# %% [markdown]
# # Deep Learning for Image Classification
#
# Welcome to deep learning for image classification tutorial!
# **In this notebook, you will**:
# - Learn the basics of PyTorch, a powerful but easy to use package for scientific computing (and deep learning)
# - Learn how to build and train a convolutional neural network for image classification.
#
# If you have never used jupyter notebooks, nor Colab notebooks, [here](https://colab.research.google.com/notebooks/welcome.ipynb) is a short intro.
#
#
# ## I. PyTorch Tutorial
#
# We will briefly go through the basics of the PyTorch package, playing with toy examples.
#
# If you know already how to use PyTorch, then you can directly go to the second part of this tutorial
#
# ## II. Training a classifier
#
# In this part, we will train a Convolutional Neural Network to classify images of 10 different classes (dogs, cats, car, ...) and see how our model performs on the test set.
#
#
# ## III. Exploring CNN Architectures
#
# This is the part where you get your hands dirty ;). Your mission is to experiment different CNN architectures and set hyperparameters in order to obtain the best accuracy on the test set!

# %% [markdown]
# The following command sets the backend of matplotlib to the 'inline' backend so that the output of plotting commands is displayed inline within frontends like the Jupyter notebook, directly below the code cell that produced it:

# %%
# %matplotlib inline

# %% [markdown]
# # I. What is PyTorch ?
#
# It’s a Python based scientific computing package targeted at two sets of audiences:
#
# - A replacement for numpy to use the power of GPUs
# - A deep learning research platform that provides maximum flexibility and speed
#
#
# ## PyTorch Basics
#
# In the next steps, we will briefly see how to use PyTorch and exploit its power:
#
# 1. PyTorch Installation
# 2. PyTorch Tensors
# 3. Numpy Bridge
# 4. Automatic differentiation
# 5. PyTorch and GPU (CUDA support)
#
#
# ### 1. Install PyTorch and Torchvision

# %%
# !pip install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# !pip install torchvision
# Out:
# Collecting torch==0.4.1 from http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
#   Downloading http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl (512.6MB)
#     100% |████████████████████████████████| 512.6MB 1.1MB/s
# tcmalloc: large alloc 1073750016 bytes == 0x5934e000 @  0x7ff3aaa002a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641
# Installing collected packages: torch
# Successfully installed torch-0.4.1
# Collecting torchvision
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 2.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Collecting pillow>=4.1.1 (from torchvision)
#   Downloading https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#     100% |████████████████████████████████| 2.0MB 9.2MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision) (0.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Installing collected packages: pillow, torchvision
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# Successfully installed pillow-5.3.0 torchvision-0.2.1

# %%
import numpy as np
# Import torch and create the alias "th"
# instead of writing torch.name_of_a_method() , we only need to write th.name_of_a_method()
# (similarly to numpy imported as np)
import torch as th

# %% [markdown]
# ### 2. PyTorch Tensors
#
# A `torch.Tensor` is a multi-dimensional matrix containing elements of a single data type.
#
# Tensors are similar to numpy’s ndarrays, but they have a super-power: Tensors can also be used on a GPU to accelerate computing.

# %% [markdown]
# #### Tensor Shape
# To know the shape of a given tensor, you can use the `.size()` method (the numpy equivalent is `.shape`)

# %%
# Display the shape of a tensor
# it can be used as a tuple
print("Tensor Shape: {}".format(ones.size()))
# Out:
# Tensor Shape: torch.Size([3, 2])

# %% [markdown]
# #### Reshape tensors
#
# To reshape tensors (e.g. flatten a 3D tensor to a 1D array), you can use the `.view()` method:
#
# - **x.view(new_shape)**: Returns a new tensor with the same data but different size. It is the equivalent of numpy function *reshape* (Gives a new shape to an array without changing its data.). You can read the full documentation [here.](http://pytorch.org/docs/master/tensors.html#torch.Tensor.view)
#
# [WARNING] when precising a new shape, you have to make sure that the number of elements is constant.
# For example, a 2D matrix of size 3x3 can only be viewed as a 1D array of size $3 \cdot 3 = 9$

# %%
# Create a 3D tensor of size 3x2x2
zeros_3d_tensor = th.zeros(3, 2, 2)
print("Original size:", zeros_3d_tensor.size())

# Reshape it to a 1D array of size 3*2*2 = 12
zeros_1d_array = zeros_3d_tensor.view(3 * 2 * 2)
print("Reshaped tensor:", zeros_1d_array.size())


# Let's view our original tensor as a 2D matrix
# If you want PyTorch to guess one remaining dimension,
# you specify '-1' instead of the actual size
zeros_2d_matrix = zeros_3d_tensor.view(-1, 2 * 2)

print("Matrix shape:", zeros_2d_matrix.size())
# Out:
# Original size: torch.Size([3, 2, 2])
# Reshaped tensor: torch.Size([12])
# Matrix shape: torch.Size([3, 4])

# %% [markdown]
# ### 3. Numpy Bridge
# WARNING: PyTorch Tensors are different from numpy arrays
# even if they have a lot in common
#
# Though, it is **easy with PyTorch to tranform Tensors to Numpy arrays and vice versa**

# %% [markdown]
# #### Numpy <-> PyTorch
#
# Creating PyTorch tensors from numpy array is done via the `torch.from_numpy()` function
# (here `th.from_numpy()` because we renamed *torch* as *th*)
#
# To transform a PyTorch tensor to a numpy array, you can simply call `.numpy()` method.

# %%
# np.float32 -> th.FloatTensor
ones_matrix = np.ones((2, 2), dtype=np.float32)

# the matrix is passed by reference:
# if we modify the original numpy array, the tensor is also edited
ones_tensor = th.from_numpy(ones_matrix)
# Convert back to a numpy matrix
numpy_matrix = ones_tensor.numpy()

print("PyTorch Tensor:")
print(ones_tensor)

print("Numpy Matrix:")
print(numpy_matrix)
# Out:
# PyTorch Tensor:
# tensor([[1., 1.],
#         [1., 1.]])
# Numpy Matrix:
# [[1. 1.]
#  [1. 1.]]

# %% [markdown]
# ### 4. Automatic Differentiation
#
# Pytorch tensors allow to **automatically compute gradients**. That is particulary useful for backpropagation.
#
# Once you finish your computation you can call `.backward()` and have all the gradients computed automatically.
#
# You can access the gradient w.r.t. this variable using `.grad`.

# %%
# We need to specify that we want to compute the gradient
# as it requires extra memory and computation
ones_tensor = th.ones(2,2, requires_grad=True)

print(ones_tensor)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)

# %% [markdown]
# To demonstrate the use of PyTorch Variable,
# let's define a simple linear transformation of a variable $x$ :
#
# $$y = a \cdot x + b$$
#
# PyTorch will allows us to automatically compute $$\frac{dy}{dx} $$

# %%
# Create a tensor and tell PyTorch
# that we want to compute the gradient
x = th.ones(1, requires_grad=True)

# Transformation constants
a = 2
b = 5

# Define the tranformation and store the result
# in a new variable
y = a * x + b

print(y)
# Out:
# tensor([7.], grad_fn=<AddBackward>)

# %% [markdown]
# Let's backprop!

# %%
y.backward()

# %% [markdown]
# `x.grad` prints the gradient:
#
# $$\frac{dy}{dx} = a$$
#
# because:
#
# $$y = a \cdot x + b$$

# %%
x.grad
# Out:
# tensor([2.])

# %% [markdown]
# You can now change the values of $a$ and $b$ see their effects on the gradient
# (HINT: `x.grad` only depends on the value of `a`)

# %% [markdown]
# ### 5. PyTorch and GPU (CUDA support)
#
# Google colab provides a CUDA enabled GPU, so we are going to use its power.
# You can move tensor to the GPU by simply using the `to()` method.
# Otherwise, PyTorch will use the CPU.
#
# Here, we will demonstrate the usefulness of the GPU on a simple matrix multiplication:

# %%
if th.cuda.is_available():
  # Create tensors
  x = th.ones(1000, 1000)
  y = 2 * x + 3
  # Do the calculation on cpu (default)
  start_time = time.time()
  # Matrix multiplication (for benchmark purpose)
  results = th.mm(x, y)
  time_cpu = time.time() - start_time
  
  # Do the same calculation but on the gpu
  # First move tensors to gpu
  x = x.to("cuda")
  y = y.to("cuda")
  start_time = time.time()
  # Matrix multiplication (for benchmark purpose)
  results = th.mm(x, y)
  time_gpu = time.time() - start_time
  
  print("Time on CPU: {:.5f}s \t Time on GPU: {:.5f}s".format(time_cpu, time_gpu))
  print("Speed up: Computation was {:.0f}X faster on GPU!".format(time_cpu / time_gpu))
  
else:
  print("You need to enable GPU accelaration in colab (runtime->change runtime type)")
# Out:
# Time on CPU: 0.03188s 	 Time on GPU: 0.00140s
# Speed up: Computation was 23X faster on GPU!

# %% [markdown]
# As expected, matrix multiplication is way faster on a GPU, so we'd better use it.

# %% [markdown]
# # II. Training a classifier
#
#
# For this tutorial, we will use the CIFAR10 dataset.
# There are 10 classes: ‘airplane’, ‘automobile’, ‘bird’, ‘cat’, ‘deer’,
# ‘dog’, ‘frog’, ‘horse’, ‘ship’, ‘truck’. The images in CIFAR-10 are of
# size 3x32x32, i.e. 3-channel color images of 32x32 pixels in size.
#
#
# ![CIFAR10](http://pytorch.org/tutorials/_images/cifar10.png)
#
#
# Training an image classifier
# ----------------------------
#
# We will do the following steps in order:
#
# 1. Load and normalize the CIFAR10 training and test datasets using
#    ``torchvision``
# 2. Define a Convolution Neural Network
# 3. Define a loss function
# 4. Train the network on the training data
# 5. Test the network on the test data

# %% [markdown]
# ### 1. Loading and normalizing CIFAR10 Dataset
#
# Using ``torchvision``, it’s extremely easy to load CIFAR10.

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# Seed the random generator to have reproducible results:

# %%
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

if th.cuda.is_available():
  # Make CuDNN Determinist
  th.backends.cudnn.deterministic = True
  th.cuda.manual_seed(seed)

# Define default device, we should use the GPU (cuda) if available
device = th.device("cuda" if th.cuda.is_available() else "cpu")

# %% [markdown]
# ### Define subset of the dataset (so it is faster to train)

# %%
from torch.utils.data.sampler import SubsetRandomSampler

n_training_samples = 40000 # Max: 50 000 - n_val_samples
n_val_samples = 5000
n_test_samples = 10000

train_sampler = SubsetRandomSampler(np.arange(n_training_samples, dtype=np.int64))
val_sampler = SubsetRandomSampler(np.arange(n_training_samples, n_training_samples + n_val_samples, dtype=np.int64))
test_sampler = SubsetRandomSampler(np.arange(n_test_samples, dtype=np.int64))
# (In the last case, indexes do not need to account for training ones because the train=False parameter in datasets.CIFAR will select from the test set)

# %% [markdown]
# The output of torchvision datasets are PILImage images of range [0, 1].
# We transform them to Tensors of normalized range [-1, 1]

# %%
import PIL
num_workers = 2
test_batch_size = 4

transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
     transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
     transforms.ToTensor(),
     transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])



train_set = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=test_batch_size, sampler=train_sampler,
                                          num_workers=num_workers)

test_set = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=test_batch_size, sampler=test_sampler,
                                         num_workers=num_workers)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# Files already downloaded and verified

# %% [markdown]
# Let us show some of the training images, for fun.

# %%
# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('{:>10}'.format(classes[labels[j]]) for j in range(test_batch_size)))
# Out:
#      horse        cat        cat      horse

# %% [markdown]
# ### 2. Define a Convolution Neural Network

# %%
# Useful imports
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ####  Forward propagation
#
# In PyTorch, there are built-in functions that carry out the convolution steps for you.
#
# - **nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0):** Convolution layer. You can read the full documentation [here](http://pytorch.org/docs/master/nn.html#conv2d)
#
# - **nn.MaxPool2d(kernel_size, stride=None, padding=0):** Max pooling layer. You can read the full documentation [here](http://pytorch.org/docs/master/nn.html#maxpool2d)
#
# - **F.relu(Z1):** computes the elementwise ReLU of Z1 (which can be any shape). You can read the full documentation [here.](http://pytorch.org/docs/master/nn.html#torch.nn.ReLU)
#
# - **x.view(new_shape)**: Returns a new tensor with the same data but different size. It is the equivalent of numpy function *reshape* (Gives a new shape to an array without changing its data). You can read the full documentation [here.](http://pytorch.org/docs/master/tensors.html#torch.Tensor.view)
#
# - **nn.Linear(in_features, out_features):** Applies a linear transformation to the incoming data: $y = Ax + b$, it is also called a fully connected layer. You can read the full documentation [here.](http://pytorch.org/docs/master/nn.html#linear-layers)

# %% [markdown]
# #### Simple Convolutional Neural Network
#
# ConvNet with one convolution layer followed by a max pooling operation,
# one fully connected layer and an output layer

# %%
class SimpleConvolutionalNetwork(nn.Module):
    def __init__(self):
        super(SimpleConvolutionalNetwork, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 18, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
        # cf comments in forward() to have step by step comments
        # on the shape (how we pass from a 3x32x32 input image to a 18x16x16 volume)
        self.fc1 = nn.Linear(18 * 16 * 16, 64) 
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        """
        Forward pass,
        x shape is (batch_size, 3, 32, 32)
        (color channel first)
        in the comments, we omit the batch_size in the shape
        """
        # shape : 3x32x32 -> 18x32x32
        x = F.relu(self.conv1(x))
        # 18x32x32 -> 18x16x16
        x = self.pool(x)
        # 18x16x16 -> 4608
        x = x.view(-1, 18 * 16 * 16)
        # 4608 -> 64
        x = F.relu(self.fc1(x))
        # 64 -> 10
        # The softmax non-linearity is applied later (cf createLossAndOptimizer() fn)
        x = self.fc2(x)
        return x

# %% [markdown]
# #### Linear Classifier

# %%
class LinearClassifier(nn.Module):
    """
    Linear Classifier
    """
    def __init__(self):
        super(LinearClassifier, self).__init__()
        self.linear = nn.Linear(32 * 32 * 3, 10)

    def forward(self, x):
        # Flatten input 3x32x32 -> 3072
        x = x.view(x.size(0), -1)
        return self.linear(x)

# %% [markdown]
# ### 3. Define a loss function and optimizer
#
# Let's use a Classification Cross-Entropy loss and ADAM (optionally, SGD with momentum). You can read more about  [optimization methods](https://pytorch.org/docs/stable/optim.html).

# %%
import torch.optim as optim

def createLossAndOptimizer(net, learning_rate=0.001):
    # it combines softmax with negative log likelihood loss
    criterion = nn.CrossEntropyLoss()  
    #optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    return criterion, optimizer

# %% [markdown]
# ### 4. Train the network
#
#
# This is when things start to get interesting.
# We simply have to loop over our data iterator, feed the inputs to the network, and optimize

# %% [markdown]
# #### Data loader

# %%
def get_train_loader(batch_size):
    return torch.utils.data.DataLoader(train_set, batch_size=batch_size, sampler=train_sampler,
                                              num_workers=num_workers)

# Use larger batch size for validation to speed up computation
val_loader = torch.utils.data.DataLoader(train_set, batch_size=128, sampler=val_sampler,
                                          num_workers=num_workers)

# %% [markdown]
# #### Training loop
# The training script: it takes ~10s per epoch with batch_size = 32

# %%
def train(net, batch_size, n_epochs, learning_rate):
    """
    Train a neural network and print statistics of the training
    
    :param net: (PyTorch Neural Network)
    :param batch_size: (int)
    :param n_epochs: (int)  Number of iterations on the training set
    :param learning_rate: (float) learning rate used by the optimizer
    """
    print("===== HYPERPARAMETERS =====")
    print("batch_size=", batch_size)
    print("n_epochs=", n_epochs)
    print("learning_rate=", learning_rate)
    print("=" * 30)
    
    train_loader = get_train_loader(batch_size)
    n_minibatches = len(train_loader)

    criterion, optimizer = createLossAndOptimizer(net, learning_rate)
    # Init variables used for plotting the loss
    train_history = []
    val_history = []

    training_start_time = time.time()
    best_error = np.inf
    best_model_path = "best_model.pth"
    
    # Move model to gpu if possible
    net = net.to(device)

    for epoch in range(n_epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        print_every = n_minibatches // 10
        start_time = time.time()
        total_train_loss = 0
        
        for i, (inputs, labels) in enumerate(train_loader):

            # Move tensors to correct device
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            total_train_loss += loss.item()

            # print every 10th of epoch
            if (i + 1) % (print_every + 1) == 0:    
                print("Epoch {}, {:d}% \t train_loss: {:.2f} took: {:.2f}s".format(
                      epoch + 1, int(100 * (i + 1) / n_minibatches), running_loss / print_every,
                      time.time() - start_time))
                running_loss = 0.0
                start_time = time.time()

        train_history.append(total_train_loss / len(train_loader))

        total_val_loss = 0
        # Do a pass on the validation set
        # We don't need to compute gradient,
        # we save memory and computation using th.no_grad()
        with th.no_grad():
          for inputs, labels in val_loader:
              # Move tensors to correct device
              inputs, labels = inputs.to(device), labels.to(device)
              # Forward pass
              predictions = net(inputs)
              val_loss = criterion(predictions, labels)
              total_val_loss += val_loss.item()
            
        val_history.append(total_val_loss / len(val_loader))
        # Save model that performs best on validation set
        if total_val_loss < best_error:
            best_error = total_val_loss
            th.save(net.state_dict(), best_model_path)

        print("Validation loss = {:.2f}".format(total_val_loss / len(val_loader)))

    print("Training Finished, took {:.2f}s".format(time.time() - training_start_time))
    
    # Load best model
    net.load_state_dict(th.load(best_model_path))
    
    return train_history, val_history

# %%
net = SimpleConvolutionalNetwork()

train_history, val_history = train(net, batch_size=32, n_epochs=20, learning_rate=0.001)
# Out:
# ===== HYPERPARAMETERS =====
# batch_size= 32
# n_epochs= 20
# learning_rate= 0.001
# ==============================
# Epoch 1, 10% 	 train_loss: 2.01 took: 1.87s
# Epoch 1, 20% 	 train_loss: 1.76 took: 1.83s
# Epoch 1, 30% 	 train_loss: 1.63 took: 1.75s
# Epoch 1, 40% 	 train_loss: 1.57 took: 1.75s
# Epoch 1, 50% 	 train_loss: 1.56 took: 1.76s
# Epoch 1, 60% 	 train_loss: 1.51 took: 1.79s
# Epoch 1, 70% 	 train_loss: 1.43 took: 1.78s
# Epoch 1, 80% 	 train_loss: 1.48 took: 1.76s
# Epoch 1, 90% 	 train_loss: 1.44 took: 1.75s
# Validation loss = 1.44
# Epoch 2, 10% 	 train_loss: 1.38 took: 1.84s
# Epoch 2, 20% 	 train_loss: 1.39 took: 1.77s
# Epoch 2, 30% 	 train_loss: 1.34 took: 1.78s
# Epoch 2, 40% 	 train_loss: 1.38 took: 1.78s
# Epoch 2, 50% 	 train_loss: 1.31 took: 1.82s
# Epoch 2, 60% 	 train_loss: 1.35 took: 1.74s
# Epoch 2, 70% 	 train_loss: 1.35 took: 1.79s
# Epoch 2, 80% 	 train_loss: 1.32 took: 1.78s
# Epoch 2, 90% 	 train_loss: 1.31 took: 1.80s
# Validation loss = 1.32
# Epoch 3, 10% 	 train_loss: 1.30 took: 1.91s
# Epoch 3, 20% 	 train_loss: 1.28 took: 1.78s
# Epoch 3, 30% 	 train_loss: 1.28 took: 1.75s
# Epoch 3, 40% 	 train_loss: 1.27 took: 1.80s
# Epoch 3, 50% 	 train_loss: 1.29 took: 1.79s
# Epoch 3, 60% 	 train_loss: 1.27 took: 1.79s
# Epoch 3, 70% 	 train_loss: 1.26 took: 1.80s
# Epoch 3, 80% 	 train_loss: 1.27 took: 1.77s
# Epoch 3, 90% 	 train_loss: 1.27 took: 1.78s
# Validation loss = 1.29
# Epoch 4, 10% 	 train_loss: 1.22 took: 1.90s
# Epoch 4, 20% 	 train_loss: 1.27 took: 1.79s
# Epoch 4, 30% 	 train_loss: 1.25 took: 1.77s
# Epoch 4, 40% 	 train_loss: 1.24 took: 1.80s
# Epoch 4, 50% 	 train_loss: 1.22 took: 1.79s
# Epoch 4, 60% 	 train_loss: 1.21 took: 1.82s
# Epoch 4, 70% 	 train_loss: 1.20 took: 1.81s
# Epoch 4, 80% 	 train_loss: 1.23 took: 1.82s
# Epoch 4, 90% 	 train_loss: 1.23 took: 1.81s
# Validation loss = 1.27
# Epoch 5, 10% 	 train_loss: 1.21 took: 1.86s
# Epoch 5, 20% 	 train_loss: 1.20 took: 1.74s
# Epoch 5, 30% 	 train_loss: 1.18 took: 1.74s
# Epoch 5, 40% 	 train_loss: 1.22 took: 1.74s
# Epoch 5, 50% 	 train_loss: 1.20 took: 1.73s
# Epoch 5, 60% 	 train_loss: 1.17 took: 1.73s
# Epoch 5, 70% 	 train_loss: 1.17 took: 1.73s
# Epoch 5, 80% 	 train_loss: 1.18 took: 1.76s
# Epoch 5, 90% 	 train_loss: 1.18 took: 1.80s
# Validation loss = 1.22
# Epoch 6, 10% 	 train_loss: 1.16 took: 1.86s
# Epoch 6, 20% 	 train_loss: 1.18 took: 1.77s
# Epoch 6, 30% 	 train_loss: 1.13 took: 1.74s
# Epoch 6, 40% 	 train_loss: 1.16 took: 1.78s
# Epoch 6, 50% 	 train_loss: 1.17 took: 1.78s
# Epoch 6, 60% 	 train_loss: 1.17 took: 1.75s
# Epoch 6, 70% 	 train_loss: 1.19 took: 1.75s
# Epoch 6, 80% 	 train_loss: 1.16 took: 1.77s
# Epoch 6, 90% 	 train_loss: 1.16 took: 1.76s
# Validation loss = 1.23
# Epoch 7, 10% 	 train_loss: 1.13 took: 1.90s
# Epoch 7, 20% 	 train_loss: 1.13 took: 1.78s
# Epoch 7, 30% 	 train_loss: 1.14 took: 1.74s
# Epoch 7, 40% 	 train_loss: 1.12 took: 1.75s
# Epoch 7, 50% 	 train_loss: 1.14 took: 1.75s
# Epoch 7, 60% 	 train_loss: 1.14 took: 1.77s
# Epoch 7, 70% 	 train_loss: 1.13 took: 1.78s
# Epoch 7, 80% 	 train_loss: 1.15 took: 1.76s
# Epoch 7, 90% 	 train_loss: 1.17 took: 1.77s
# Validation loss = 1.20
# Epoch 8, 10% 	 train_loss: 1.14 took: 1.90s
# Epoch 8, 20% 	 train_loss: 1.13 took: 1.78s
# Epoch 8, 30% 	 train_loss: 1.13 took: 1.75s
# Epoch 8, 40% 	 train_loss: 1.09 took: 1.76s
# Epoch 8, 50% 	 train_loss: 1.13 took: 1.76s
# Epoch 8, 60% 	 train_loss: 1.11 took: 1.77s
# Epoch 8, 70% 	 train_loss: 1.13 took: 1.73s
# Epoch 8, 80% 	 train_loss: 1.13 took: 1.75s
# Epoch 8, 90% 	 train_loss: 1.16 took: 1.78s
# Validation loss = 1.19
# Epoch 9, 10% 	 train_loss: 1.11 took: 1.85s
# Epoch 9, 20% 	 train_loss: 1.11 took: 1.74s
# Epoch 9, 30% 	 train_loss: 1.10 took: 1.75s
# Epoch 9, 40% 	 train_loss: 1.10 took: 1.74s
# Epoch 9, 50% 	 train_loss: 1.07 took: 1.74s
# Epoch 9, 60% 	 train_loss: 1.12 took: 1.74s
# Epoch 9, 70% 	 train_loss: 1.10 took: 1.74s
# Epoch 9, 80% 	 train_loss: 1.11 took: 1.74s
# Epoch 9, 90% 	 train_loss: 1.13 took: 1.72s
# Validation loss = 1.20
# Epoch 10, 10% 	 train_loss: 1.07 took: 1.85s
# Epoch 10, 20% 	 train_loss: 1.07 took: 1.75s
# Epoch 10, 30% 	 train_loss: 1.07 took: 1.77s
# Epoch 10, 40% 	 train_loss: 1.10 took: 1.77s
# Epoch 10, 50% 	 train_loss: 1.09 took: 1.75s
# Epoch 10, 60% 	 train_loss: 1.11 took: 1.73s
# Epoch 10, 70% 	 train_loss: 1.12 took: 1.75s
# Epoch 10, 80% 	 train_loss: 1.07 took: 1.73s
# Epoch 10, 90% 	 train_loss: 1.10 took: 1.79s
# Validation loss = 1.18
# Epoch 11, 10% 	 train_loss: 1.08 took: 1.86s
# Epoch 11, 20% 	 train_loss: 1.10 took: 1.77s
# Epoch 11, 30% 	 train_loss: 1.07 took: 1.75s
# Epoch 11, 40% 	 train_loss: 1.08 took: 1.76s
# Epoch 11, 50% 	 train_loss: 1.09 took: 1.80s
# Epoch 11, 60% 	 train_loss: 1.06 took: 1.79s
# Epoch 11, 70% 	 train_loss: 1.09 took: 1.73s
# Epoch 11, 80% 	 train_loss: 1.08 took: 1.76s
# Epoch 11, 90% 	 train_loss: 1.08 took: 1.76s
# Validation loss = 1.17
# Epoch 12, 10% 	 train_loss: 1.05 took: 1.90s
# Epoch 12, 20% 	 train_loss: 1.05 took: 1.76s
# Epoch 12, 30% 	 train_loss: 1.09 took: 1.74s
# Epoch 12, 40% 	 train_loss: 1.06 took: 1.77s
# Epoch 12, 50% 	 train_loss: 1.06 took: 1.75s
# Epoch 12, 60% 	 train_loss: 1.06 took: 1.80s
# Epoch 12, 70% 	 train_loss: 1.08 took: 1.76s
# Epoch 12, 80% 	 train_loss: 1.09 took: 1.77s
# Epoch 12, 90% 	 train_loss: 1.08 took: 1.74s
# Validation loss = 1.17
# Epoch 13, 10% 	 train_loss: 1.04 took: 1.89s
# Epoch 13, 20% 	 train_loss: 1.08 took: 1.76s
# Epoch 13, 30% 	 train_loss: 1.06 took: 1.74s
# Epoch 13, 40% 	 train_loss: 1.04 took: 1.74s
# Epoch 13, 50% 	 train_loss: 1.08 took: 1.77s
# Epoch 13, 60% 	 train_loss: 1.08 took: 1.78s
# Epoch 13, 70% 	 train_loss: 1.06 took: 1.76s
# Epoch 13, 80% 	 train_loss: 1.07 took: 1.80s
# Epoch 13, 90% 	 train_loss: 1.07 took: 1.76s
# Validation loss = 1.11
# Epoch 14, 10% 	 train_loss: 1.06 took: 1.90s
# Epoch 14, 20% 	 train_loss: 1.04 took: 1.80s
# Epoch 14, 30% 	 train_loss: 1.04 took: 1.77s
# Epoch 14, 40% 	 train_loss: 1.04 took: 1.79s
# Epoch 14, 50% 	 train_loss: 1.06 took: 1.80s
# Epoch 14, 60% 	 train_loss: 1.07 took: 1.74s
# Epoch 14, 70% 	 train_loss: 1.05 took: 1.77s
# Epoch 14, 80% 	 train_loss: 1.04 took: 1.76s
# Epoch 14, 90% 	 train_loss: 1.07 took: 1.80s
# Validation loss = 1.16
# Epoch 15, 10% 	 train_loss: 1.04 took: 1.90s
# Epoch 15, 20% 	 train_loss: 1.04 took: 1.77s
# Epoch 15, 30% 	 train_loss: 1.05 took: 1.82s
# Epoch 15, 40% 	 train_loss: 1.04 took: 1.77s
# Epoch 15, 50% 	 train_loss: 1.02 took: 1.76s
# Epoch 15, 60% 	 train_loss: 1.06 took: 1.79s
# Epoch 15, 70% 	 train_loss: 1.02 took: 1.79s
# Epoch 15, 80% 	 train_loss: 1.03 took: 1.78s
# Epoch 15, 90% 	 train_loss: 1.07 took: 1.74s
# Validation loss = 1.13
# Epoch 16, 10% 	 train_loss: 1.02 took: 1.93s
# Epoch 16, 20% 	 train_loss: 1.05 took: 1.79s
# Epoch 16, 30% 	 train_loss: 1.03 took: 1.78s
# Epoch 16, 40% 	 train_loss: 1.03 took: 1.79s
# Epoch 16, 50% 	 train_loss: 1.05 took: 1.77s
# Epoch 16, 60% 	 train_loss: 1.08 took: 1.81s
# Epoch 16, 70% 	 train_loss: 1.02 took: 1.78s
# Epoch 16, 80% 	 train_loss: 1.05 took: 1.75s
# Epoch 16, 90% 	 train_loss: 1.05 took: 1.78s
# Validation loss = 1.15
# Epoch 17, 10% 	 train_loss: 1.04 took: 1.90s
# Epoch 17, 20% 	 train_loss: 1.02 took: 1.81s
# Epoch 17, 30% 	 train_loss: 1.03 took: 1.93s
# Epoch 17, 40% 	 train_loss: 1.06 took: 1.81s
# Epoch 17, 50% 	 train_loss: 1.03 took: 1.82s
# Epoch 17, 60% 	 train_loss: 1.04 took: 1.79s
# Epoch 17, 70% 	 train_loss: 1.03 took: 1.77s
# Epoch 17, 80% 	 train_loss: 1.03 took: 1.76s
# Epoch 17, 90% 	 train_loss: 1.08 took: 1.83s
# Validation loss = 1.12
# Epoch 18, 10% 	 train_loss: 1.03 took: 1.96s
# Epoch 18, 20% 	 train_loss: 1.05 took: 1.82s
# Epoch 18, 30% 	 train_loss: 1.03 took: 1.83s
# Epoch 18, 40% 	 train_loss: 1.03 took: 1.83s
# Epoch 18, 50% 	 train_loss: 1.02 took: 1.82s
# Epoch 18, 60% 	 train_loss: 1.02 took: 1.84s
# Epoch 18, 70% 	 train_loss: 1.00 took: 1.83s
# Epoch 18, 80% 	 train_loss: 1.05 took: 1.84s
# Epoch 18, 90% 	 train_loss: 1.02 took: 1.79s
# Validation loss = 1.14
# Epoch 19, 10% 	 train_loss: 1.00 took: 1.88s
# Epoch 19, 20% 	 train_loss: 1.03 took: 1.84s
# Epoch 19, 30% 	 train_loss: 1.00 took: 1.91s
# Epoch 19, 40% 	 train_loss: 0.99 took: 1.93s
# Epoch 19, 50% 	 train_loss: 1.03 took: 1.92s
# Epoch 19, 60% 	 train_loss: 1.04 took: 1.93s
# Epoch 19, 70% 	 train_loss: 1.08 took: 1.91s
# Epoch 19, 80% 	 train_loss: 1.04 took: 1.96s
# Epoch 19, 90% 	 train_loss: 1.01 took: 1.92s
# Validation loss = 1.15
# Epoch 20, 10% 	 train_loss: 1.00 took: 1.98s
# Epoch 20, 20% 	 train_loss: 1.01 took: 1.84s
# Epoch 20, 30% 	 train_loss: 1.01 took: 1.78s
# Epoch 20, 40% 	 train_loss: 1.02 took: 1.82s
# Epoch 20, 50% 	 train_loss: 1.03 took: 1.94s
# Epoch 20, 60% 	 train_loss: 1.02 took: 1.93s
# Epoch 20, 70% 	 train_loss: 1.01 took: 1.94s
# Epoch 20, 80% 	 train_loss: 1.04 took: 1.90s
# Epoch 20, 90% 	 train_loss: 1.00 took: 1.92s
# Validation loss = 1.13
# Training Finished, took 387.87s

# %% [markdown]
# Now, let's look at the evolution of the losses

# %%
plot_losses(train_history, val_history)

# %% [markdown]
# ### 5. Test the network on the test data
#
#
# We have trained the network for 2 passes over the training dataset.
# But we need to check if the network has learnt anything at all.
#
# We will check this by predicting the class label that the neural network
# outputs, and checking it against the ground-truth. If the prediction is
# correct, we add the sample to the list of correct predictions.
#
# Okay, first step. Let us display an image from the test set to get familiar.

# %%
try:
  images, labels = next(iter(test_loader))
except EOFError:
  pass

# print images
imshow(torchvision.utils.make_grid(images))
print("Ground truth:\n")

print(' '.join('{:>10}'.format(classes[labels[j]]) for j in range(test_batch_size)))
# Out:
# Ground truth:
#
#      plane        dog       frog      horse

# %% [markdown]
# Okay, now let us see what the neural network thinks these examples above are:

# %%
outputs = net(images.to(device))
print(outputs.size())
# Out:
# torch.Size([4, 10])

# %% [markdown]
# The outputs are energies for the 10 classes.
# The higher the energy for a class, the more the network
# thinks that the image is from that particular class.
# So, let's get the index of the highest energy:

# %%
_, predicted = torch.max(outputs, 1)

print("Predicted:\n")
imshow(torchvision.utils.make_grid(images))

print(' '.join('{:>10}'.format(classes[predicted[j]]) for j in range(test_batch_size)))
# Out:
# Predicted:
#
#      plane      horse       frog       ship

# %% [markdown]
# The results seem pretty good.
#
# Let us look at how the network performs on the whole test set.

# %%
def dataset_accuracy(net, data_loader, name=""):
    net = net.to(device)
    correct = 0
    total = 0
    for images, labels in data_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum()
    accuracy = 100 * float(correct) / total
    print('Accuracy of the network on the {} {} images: {:.2f} %'.format(total, name, accuracy))

def train_set_accuracy(net):
    dataset_accuracy(net, train_loader, "train")

def val_set_accuracy(net):
    dataset_accuracy(net, val_loader, "validation")  
    
def test_set_accuracy(net):
    dataset_accuracy(net, test_loader, "test")

def compute_accuracy(net):
    train_set_accuracy(net)
    val_set_accuracy(net)
    test_set_accuracy(net)
    
print("Computing accuracy...")
compute_accuracy(net)
# Out:
# Computing accuracy...
# Accuracy of the network on the 40000 train images: 63.83 %
# Accuracy of the network on the 5000 validation images: 60.46 %
# Accuracy of the network on the 10000 test images: 61.48 %

# %% [markdown]
# That initial 59.78 % on the test set of images looks waaay better than chance, which is 10% accuracy (randomly picking
# a class out of 10 classes).
# Seems like the network learnt something.
# As a baseline, a linear model achieves around 30% accuracy.
#
# What are the classes that performed well, and the classes that did not perform well?

# %%
def accuracy_per_class(net):
    net = net.to(device)
    n_classes = 10
    # (real, predicted)
    confusion_matrix = np.zeros((n_classes, n_classes), dtype=np.int64)

    for images, labels in test_loader:
        images, labels = images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        for i in range(test_batch_size):
            confusion_matrix[labels[i], predicted[i]] += 1
            label = labels[i]

    print("{:<10} {:^10}".format("Class", "Accuracy (%)"))
    for i in range(n_classes):
        class_total = confusion_matrix[i, :].sum()
        class_correct = confusion_matrix[i, i]
        percentage_correct = 100.0 * float(class_correct) / class_total
        
        print('{:<10} {:^10.2f}'.format(classes[i], percentage_correct))
    return confusion_matrix

confusion_matrix = accuracy_per_class(net)
# Out:
# Class      Accuracy (%)
# plane        56.60
# car          76.40
# bird         51.50
# cat          48.90
# deer         48.10
# dog          46.60
# frog         74.00
# horse        69.30
# ship         79.20
# truck        64.00

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# Let's look at what type of error our networks makes...
# It seems that our network is pretty good at classifying ships,
# but has some difficulties to differentiate cats and dogs.
# Also, it classifies a lot of trucks as cars.

# %%
# Plot normalized confusion matrix
plot_confusion_matrix(confusion_matrix, classes, normalize=True,
                      title='Normalized confusion matrix')

# Plot non-normalized confusion matrix
plot_confusion_matrix(confusion_matrix, classes,
                      title='Confusion matrix, without normalization')

# %% [markdown]
# # III. Exploring CNN Architectures
#
# Now, it is your turn to build a Convolutional Neural Network. The goal of this section is to explore different CNN architectures and set hyperparameters in order to obtain the best accuracy on the **test** set!
#
# The network that you have to tweak is called **MyConvolutionalNetwork**.
#
# You can start changing the batch_size, number of epochs and then try adding more convolutional layers.

# %% [markdown]
# ### PyTorch functions to build the network
# - **nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0):** Convolution layer. You can read the full documentation [here](http://pytorch.org/docs/master/nn.html#conv2d)
#
# - **nn.MaxPool2d(kernel_size, stride=None, padding=0):** Max pooling layer. You can read the full documentation [here](http://pytorch.org/docs/master/nn.html#maxpool2d)
#
# - **F.relu(Z1):** computes the element-wise ReLU of Z1 (which can be of any shape). You can read the full documentation [here.](http://pytorch.org/docs/master/nn.html#torch.nn.ReLU)
#
# - **x.view(new_shape)**: Returns a new tensor with the same data but different size. It is the equivalent of numpy function *reshape* (Gives a new shape to an array without changing its data.). You can read the full documentation [here.](http://pytorch.org/docs/master/tensors.html#torch.Tensor.view)
#
# - **nn.Linear(in_features, out_features):** Applies a linear transformation to the incoming data: $y = Ax + b$, it is also called a fully connected (fc) layer. You can read the full documentation [here.](http://pytorch.org/docs/master/nn.html#linear-layers)

# %% [markdown]
# **Convolution Formulas**:
#
# The formulas relating the output shape $(C_2, H_2, W_2)$ of the convolution to the input shape $(C_1, H_1, W_1)$ are:
#
#
# $$ H_2 = \lfloor \frac{H_1 - kernel\_size + 2 \times padding}{stride} \rfloor +1 $$
#
# $$ W_2 = \lfloor \frac{W_1 - kernel\_size + 2 \times padding}{stride} \rfloor +1 $$
#
# $$ C_2 = \text{number of filters used in the convolution}$$
#
# NOTE: $C_2 = C_1$ in the case of max pooling
#
# where:
# - $H_2$: height of the output volume
# - $W_2$: width of the output volume
# - $C_1$: in_channels, number of channels in the input volume
# - $C_2$: out_channels

# %%
def get_output_size(in_size, kernel_size, stride=1, padding=0):
    """
    Get the output size given all the parameters of the convolution
    :param in_size: (int) input size
    :param kernel_size: (int)
    :param stride: (int)
    :param paddind: (int)
    :return: (int)
    """
    return int((in_size - kernel_size + 2 * padding) / stride) + 1

# %% [markdown]
# #### Example of use of helper method get_output_size()
#
# Let's assume you have an *input volume of size 3x32x32* (where 3 is the number of channels)
# and you use a 2D convolution with the following parameters:
#
# ```python
# conv1 = nn.Conv2d(3, 18, kernel_size=7, stride=2, padding=1)
# ```
# then, the size of the output volume is 18x?x? (because we have 18 filters) where ? is given by the convolution formulas (see above).
#
# **get_output_size()** function allows to compute that size:
#
# ```
# out_size = get_output_size(in_size=32, kernel_size=7, stride=2, padding=1)
# print(out_size) # prints 14
# ```
#
# That is to say, *the output volume is 18x14x14*

# %%
out_size = get_output_size(in_size=32, kernel_size=3, stride=1, padding=1)
print(out_size)
# Out:
# 32

# %% [markdown]
# Below is the neural network you have to edit:

# %%
class MyConvolutionalNetwork(nn.Module):
    def __init__(self):
        super(MyConvolutionalNetwork, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

        #### START CODE: ADD NEW LAYERS ####
        # (do not forget to update `flattened_size`:
        # the input size of the first fully connected layer self.fc1)
        # self.conv2 = ...
        
        self.layer2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.layer3 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.layer4 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.layer5 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.layer6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.layer7 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.layer8 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.layer9 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.layer10 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
        
        self.bn1 = nn.BatchNorm2d(16)
        self.bn2 = nn.BatchNorm2d(32)
        self.bn3 = nn.BatchNorm2d(64)
        self.bn4 = nn.BatchNorm2d(128)
        self.bn5 = nn.BatchNorm2d(256)
        self.bn6 = nn.BatchNorm2d(512)
        self.bn7 = nn.BatchNorm2d(1024)
        self.bn8 = nn.BatchNorm2d(2048)
        
        self.dropout = nn.Dropout2d(p = 0.2)
        # Size of the output of the last convolution:
        self.flattened_size = 4096
        ### END CODE ###
        
        self.fc1 = nn.Linear(self.flattened_size, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        """
        Forward pass,
        x shape is (batch_size, 3, 32, 32)
        (color channel first)
        in the comments, we omit the batch_size in the shape
        """
        # shape : 3x32x32 -> 18x32x32
        x = self.bn1(F.relu(self.conv1(x)))
        # 18x32x32 -> 18x16x16
        x = self.bn2(F.relu(self.layer2(x)))
        x = self.pool(x)
        x = self.bn2(F.relu(self.layer3(x)))
        x = self.pool(x)
        x = self.bn3(F.relu(self.layer4(x)))
        x = self.bn4(F.relu(self.layer5(x)))
        x = self.bn4(F.relu(self.layer6(x)))
        x = self.pool(x)
        x = self.bn5(F.relu(self.layer7(x)))
        x = self.bn6(F.relu(self.layer8(x)))
        x = self.pool(x)
        x = self.bn6(F.relu(self.layer9(x)))
        x = self.bn7(F.relu(self.layer10(x)))
        #x = F.relu(self.layer7(x))

        #x = self.layer7(x)
        
        
        #### START CODE: USE YOUR NEW LAYERS HERE ####
        # x = ...
        
        #### END CODE ####
        
        # Check the output size
        output_size = np.prod(x.size()[1:])
        assert output_size == self.flattened_size,\
                "self.flattened_size is invalid {} != {}".format(output_size, self.flattened_size)
        
        # 18x16x16 -> 4608
        x = x.view(-1, self.flattened_size)
        # 4608 -> 64
        x = F.relu(self.fc1(x))
        x = self.dropout(x)

        # 64 -> 10
        x = self.fc2(x)
        return x

# %%
net = MyConvolutionalNetwork()
train_history, val_history = train(net, batch_size=32, n_epochs=20, learning_rate=0.0005)
# Out:
# ===== HYPERPARAMETERS =====
# batch_size= 32
# n_epochs= 20
# learning_rate= 0.0005
# ==============================
# Epoch 1, 10% 	 train_loss: 2.00 took: 5.10s
# Epoch 1, 20% 	 train_loss: 1.82 took: 5.07s
# Epoch 1, 30% 	 train_loss: 1.70 took: 5.02s
# Epoch 1, 40% 	 train_loss: 1.60 took: 4.95s
# Epoch 1, 50% 	 train_loss: 1.58 took: 4.95s
# Epoch 1, 60% 	 train_loss: 1.48 took: 5.00s
# Epoch 1, 70% 	 train_loss: 1.48 took: 5.07s
# Epoch 1, 80% 	 train_loss: 1.45 took: 5.03s
# Epoch 1, 90% 	 train_loss: 1.41 took: 5.06s
# Validation loss = 1.35
# Epoch 2, 10% 	 train_loss: 1.29 took: 5.09s
# Epoch 2, 20% 	 train_loss: 1.34 took: 5.17s
# Epoch 2, 30% 	 train_loss: 1.27 took: 5.23s
# Epoch 2, 40% 	 train_loss: 1.28 took: 5.17s
# Epoch 2, 50% 	 train_loss: 1.25 took: 5.03s
# Epoch 2, 60% 	 train_loss: 1.23 took: 5.04s
# Epoch 2, 70% 	 train_loss: 1.17 took: 5.09s
# Epoch 2, 80% 	 train_loss: 1.21 took: 5.15s
# Epoch 2, 90% 	 train_loss: 1.18 took: 5.14s
# Validation loss = 1.15
# Epoch 3, 10% 	 train_loss: 1.12 took: 5.05s
# Epoch 3, 20% 	 train_loss: 1.11 took: 5.00s
# Epoch 3, 30% 	 train_loss: 1.08 took: 5.00s
# Epoch 3, 40% 	 train_loss: 1.10 took: 5.05s
# Epoch 3, 50% 	 train_loss: 1.05 took: 5.03s
# Epoch 3, 60% 	 train_loss: 1.04 took: 4.99s
# Epoch 3, 70% 	 train_loss: 1.00 took: 5.02s
# Epoch 3, 80% 	 train_loss: 1.03 took: 5.07s
# Epoch 3, 90% 	 train_loss: 1.00 took: 5.03s
# Validation loss = 0.99
# Epoch 4, 10% 	 train_loss: 0.98 took: 5.02s
# Epoch 4, 20% 	 train_loss: 0.95 took: 4.97s
# Epoch 4, 30% 	 train_loss: 0.97 took: 5.00s
# Epoch 4, 40% 	 train_loss: 0.94 took: 4.94s
# Epoch 4, 50% 	 train_loss: 0.92 took: 4.97s
# Epoch 4, 60% 	 train_loss: 0.92 took: 5.08s
# Epoch 4, 70% 	 train_loss: 0.89 took: 5.09s
# Epoch 4, 80% 	 train_loss: 0.91 took: 5.06s
# Epoch 4, 90% 	 train_loss: 0.90 took: 4.99s
# Validation loss = 0.90
# Epoch 5, 10% 	 train_loss: 0.85 took: 5.04s
# Epoch 5, 20% 	 train_loss: 0.87 took: 4.99s
# Epoch 5, 30% 	 train_loss: 0.85 took: 5.07s
# Epoch 5, 40% 	 train_loss: 0.85 took: 5.07s
# Epoch 5, 50% 	 train_loss: 0.84 took: 5.07s
# Epoch 5, 60% 	 train_loss: 0.81 took: 5.00s
# Epoch 5, 70% 	 train_loss: 0.82 took: 5.04s
# Epoch 5, 80% 	 train_loss: 0.79 took: 5.10s
# Epoch 5, 90% 	 train_loss: 0.83 took: 5.14s
# Validation loss = 0.87
# Epoch 6, 10% 	 train_loss: 0.76 took: 5.03s
# Epoch 6, 20% 	 train_loss: 0.75 took: 5.00s
# Epoch 6, 30% 	 train_loss: 0.76 took: 5.00s
# Epoch 6, 40% 	 train_loss: 0.74 took: 5.00s
# Epoch 6, 50% 	 train_loss: 0.76 took: 5.09s
# Epoch 6, 60% 	 train_loss: 0.75 took: 5.00s
# Epoch 6, 70% 	 train_loss: 0.77 took: 5.02s
# Epoch 6, 80% 	 train_loss: 0.78 took: 4.96s
# Epoch 6, 90% 	 train_loss: 0.79 took: 4.98s
# Validation loss = 0.74
# Epoch 7, 10% 	 train_loss: 0.71 took: 5.08s
# Epoch 7, 20% 	 train_loss: 0.69 took: 5.10s
# Epoch 7, 30% 	 train_loss: 0.71 took: 5.02s
# Epoch 7, 40% 	 train_loss: 0.68 took: 5.02s
# Epoch 7, 50% 	 train_loss: 0.71 took: 5.05s
# Epoch 7, 60% 	 train_loss: 0.71 took: 5.03s
# Epoch 7, 70% 	 train_loss: 0.73 took: 5.01s
# Epoch 7, 80% 	 train_loss: 0.70 took: 5.01s
# Epoch 7, 90% 	 train_loss: 0.69 took: 5.04s
# Validation loss = 0.76
# Epoch 8, 10% 	 train_loss: 0.67 took: 5.16s
# Epoch 8, 20% 	 train_loss: 0.66 took: 5.25s
# Epoch 8, 30% 	 train_loss: 0.65 took: 5.14s
# Epoch 8, 40% 	 train_loss: 0.68 took: 5.08s
# Epoch 8, 50% 	 train_loss: 0.66 took: 5.14s
# Epoch 8, 60% 	 train_loss: 0.64 took: 5.13s
# Epoch 8, 70% 	 train_loss: 0.68 took: 5.09s
# Epoch 8, 80% 	 train_loss: 0.65 took: 4.96s
# Epoch 8, 90% 	 train_loss: 0.66 took: 5.06s
# Validation loss = 0.70
# Epoch 9, 10% 	 train_loss: 0.63 took: 5.04s
# Epoch 9, 20% 	 train_loss: 0.61 took: 5.12s
# Epoch 9, 30% 	 train_loss: 0.62 took: 5.12s
# Epoch 9, 40% 	 train_loss: 0.61 took: 5.11s
# Epoch 9, 50% 	 train_loss: 0.62 took: 5.01s
# Epoch 9, 60% 	 train_loss: 0.63 took: 5.02s
# Epoch 9, 70% 	 train_loss: 0.62 took: 5.02s
# Epoch 9, 80% 	 train_loss: 0.62 took: 5.10s
# Epoch 9, 90% 	 train_loss: 0.64 took: 5.14s
# Validation loss = 0.68
# Epoch 10, 10% 	 train_loss: 0.55 took: 5.05s
# Epoch 10, 20% 	 train_loss: 0.57 took: 5.05s
# Epoch 10, 30% 	 train_loss: 0.57 took: 5.09s
# Epoch 10, 40% 	 train_loss: 0.59 took: 5.09s
# Epoch 10, 50% 	 train_loss: 0.60 took: 4.94s
# Epoch 10, 60% 	 train_loss: 0.60 took: 5.04s
# Epoch 10, 70% 	 train_loss: 0.55 took: 5.07s
# Epoch 10, 80% 	 train_loss: 0.57 took: 5.17s
# Epoch 10, 90% 	 train_loss: 0.60 took: 5.04s
# Validation loss = 0.64
# Epoch 11, 10% 	 train_loss: 0.54 took: 5.04s
# Epoch 11, 20% 	 train_loss: 0.52 took: 4.97s
# Epoch 11, 30% 	 train_loss: 0.56 took: 5.04s
# Epoch 11, 40% 	 train_loss: 0.52 took: 5.10s
# Epoch 11, 50% 	 train_loss: 0.56 took: 5.01s
# Epoch 11, 60% 	 train_loss: 0.53 took: 5.00s
# Epoch 11, 70% 	 train_loss: 0.59 took: 5.00s
# Epoch 11, 80% 	 train_loss: 0.55 took: 4.97s
# Epoch 11, 90% 	 train_loss: 0.56 took: 5.01s
# Validation loss = 0.65
# Epoch 12, 10% 	 train_loss: 0.50 took: 5.05s
# Epoch 12, 20% 	 train_loss: 0.49 took: 5.06s
# Epoch 12, 30% 	 train_loss: 0.49 took: 4.97s
# Epoch 12, 40% 	 train_loss: 0.49 took: 5.04s
# Epoch 12, 50% 	 train_loss: 0.53 took: 5.00s
# Epoch 12, 60% 	 train_loss: 0.52 took: 5.06s
# Epoch 12, 70% 	 train_loss: 0.54 took: 5.09s
# Epoch 12, 80% 	 train_loss: 0.53 took: 5.06s
# Epoch 12, 90% 	 train_loss: 0.55 took: 5.14s
# Validation loss = 0.66
# Epoch 13, 10% 	 train_loss: 0.46 took: 5.11s
# Epoch 13, 20% 	 train_loss: 0.47 took: 4.96s
# Epoch 13, 30% 	 train_loss: 0.52 took: 5.00s
# Epoch 13, 40% 	 train_loss: 0.46 took: 4.97s
# Epoch 13, 50% 	 train_loss: 0.49 took: 5.05s
# Epoch 13, 60% 	 train_loss: 0.50 took: 4.95s
# Epoch 13, 70% 	 train_loss: 0.50 took: 4.97s
# Epoch 13, 80% 	 train_loss: 0.50 took: 5.00s
# Epoch 13, 90% 	 train_loss: 0.49 took: 4.96s
# Validation loss = 0.63
# Epoch 14, 10% 	 train_loss: 0.45 took: 5.13s
# Epoch 14, 20% 	 train_loss: 0.47 took: 5.27s
# Epoch 14, 30% 	 train_loss: 0.45 took: 5.06s
# Epoch 14, 40% 	 train_loss: 0.47 took: 4.99s
# Epoch 14, 50% 	 train_loss: 0.47 took: 5.03s
# Epoch 14, 60% 	 train_loss: 0.46 took: 5.01s
# Epoch 14, 70% 	 train_loss: 0.44 took: 5.05s
# Epoch 14, 80% 	 train_loss: 0.47 took: 5.09s
# Epoch 14, 90% 	 train_loss: 0.46 took: 5.05s
# Validation loss = 0.64
# Epoch 15, 10% 	 train_loss: 0.39 took: 5.09s
# Epoch 15, 20% 	 train_loss: 0.46 took: 5.02s
# Epoch 15, 30% 	 train_loss: 0.44 took: 5.07s
# Epoch 15, 40% 	 train_loss: 0.41 took: 4.93s
# Epoch 15, 50% 	 train_loss: 0.42 took: 4.98s
# Epoch 15, 60% 	 train_loss: 0.44 took: 5.07s
# Epoch 15, 70% 	 train_loss: 0.45 took: 5.28s
# Epoch 15, 80% 	 train_loss: 0.45 took: 5.06s
# Epoch 15, 90% 	 train_loss: 0.47 took: 5.05s
# Validation loss = 0.58
# Epoch 16, 10% 	 train_loss: 0.40 took: 5.05s
# Epoch 16, 20% 	 train_loss: 0.39 took: 5.03s
# Epoch 16, 30% 	 train_loss: 0.42 took: 5.09s
# Epoch 16, 40% 	 train_loss: 0.41 took: 5.00s
# Epoch 16, 50% 	 train_loss: 0.42 took: 5.04s
# Epoch 16, 60% 	 train_loss: 0.41 took: 5.09s
# Epoch 16, 70% 	 train_loss: 0.43 took: 5.09s
# Epoch 16, 80% 	 train_loss: 0.42 took: 5.07s
# Epoch 16, 90% 	 train_loss: 0.42 took: 5.03s
# Validation loss = 0.61
# Epoch 17, 10% 	 train_loss: 0.36 took: 5.11s
# Epoch 17, 20% 	 train_loss: 0.38 took: 5.06s
# Epoch 17, 30% 	 train_loss: 0.39 took: 5.03s
# Epoch 17, 40% 	 train_loss: 0.38 took: 5.09s
# Epoch 17, 50% 	 train_loss: 0.40 took: 5.06s
# Epoch 17, 60% 	 train_loss: 0.41 took: 5.02s
# Epoch 17, 70% 	 train_loss: 0.40 took: 5.17s
# Epoch 17, 80% 	 train_loss: 0.41 took: 5.05s
# Epoch 17, 90% 	 train_loss: 0.40 took: 5.07s
# Validation loss = 0.57
# Epoch 18, 10% 	 train_loss: 0.33 took: 5.06s
# Epoch 18, 20% 	 train_loss: 0.36 took: 5.00s
# Epoch 18, 30% 	 train_loss: 0.35 took: 4.93s
# Epoch 18, 40% 	 train_loss: 0.39 took: 4.96s
# Epoch 18, 50% 	 train_loss: 0.38 took: 4.98s
# Epoch 18, 60% 	 train_loss: 0.37 took: 4.98s
# Epoch 18, 70% 	 train_loss: 0.38 took: 5.00s
# Epoch 18, 80% 	 train_loss: 0.38 took: 5.00s
# Epoch 18, 90% 	 train_loss: 0.39 took: 5.05s
# Validation loss = 0.58
# Epoch 19, 10% 	 train_loss: 0.37 took: 5.09s
# Epoch 19, 20% 	 train_loss: 0.35 took: 5.06s
# Epoch 19, 30% 	 train_loss: 0.37 took: 5.01s
# Epoch 19, 40% 	 train_loss: 0.35 took: 5.07s
# Epoch 19, 50% 	 train_loss: 0.37 took: 5.02s
# Epoch 19, 60% 	 train_loss: 0.36 took: 5.06s
# Epoch 19, 70% 	 train_loss: 0.34 took: 4.98s
# Epoch 19, 80% 	 train_loss: 0.36 took: 5.02s
# Epoch 19, 90% 	 train_loss: 0.37 took: 5.02s
# Validation loss = 0.62
# Epoch 20, 10% 	 train_loss: 0.34 took: 5.15s
# Epoch 20, 20% 	 train_loss: 0.32 took: 5.03s
# Epoch 20, 30% 	 train_loss: 0.35 took: 5.03s
# Epoch 20, 40% 	 train_loss: 0.32 took: 5.03s
# Epoch 20, 50% 	 train_loss: 0.34 took: 4.93s
# Epoch 20, 60% 	 train_loss: 0.36 took: 4.97s
# Epoch 20, 70% 	 train_loss: 0.36 took: 5.05s
# Epoch 20, 80% 	 train_loss: 0.34 took: 5.05s
# Epoch 20, 90% 	 train_loss: 0.34 took: 5.03s
# Validation loss = 0.62
# Training Finished, took 1042.35s

# %% [markdown]
# ### Losses Plot

# %%
plot_losses(train_history, val_history)

# %% [markdown]
# ### Accuracy of the trained model

# %%
compute_accuracy(net)
# Out:
# Accuracy of the network on the 40000 train images: 80.19 %
# Accuracy of the network on the 5000 validation images: 80.98 %
# Accuracy of the network on the 10000 test images: 73.99 %

# %% [markdown]
# **Baseline: Simple Convolutional Neural Network (form part II)**
#
# <table>
# <tr>
#     <td>Accuracy on the test set:</td>
#     <td>59.98 %</td>
# </tr>
# </table>

# %%
confusion_matrix = accuracy_per_class(net)
# Out:
# Class      Accuracy (%)
# plane        76.10
# car          87.00
# bird         63.70
# cat          55.10
# deer         65.50
# dog          66.90
# frog         72.40
# horse        79.10
# ship         79.40
# truck        81.00

# %%
plot_confusion_matrix(confusion_matrix, classes,
                      title='Confusion matrix, without normalization')

# %% [markdown]
# ## Conclusion
#
# We used a pseudo VGG-net for the architecture of the neural network. This architecture is composed of 7 different convolutional layers coupled with Max pooling operations. The aim of these layers is to extract the essential information useful to give sense to the images in order to label them. In addition to this, we used batch normalization to improve the performance and the stability of our neural network, as well as dropout to reduce overfitting.
#
# Using the following hyperparameters we achieve accuracy on test set between 72% and 74%
# *   batch_size = 32
# *   n_epochs = 10
# *   learning_rate=5e-4
# *   Size of the training set = 40 000
# *   Size of the validation set = 5000
#
# We noticed when changing the batch size, we should consider changing the number of epochs to have approximately same number of the weight updates.
# However increasing the batch size and the number of epoch (to 5612 and 50 for example) helped minimize the train loss but not the validation function which stagnated around 0.68.
#
# We also noticed that the the training phase is long and that is due to the important number of data in the training set and the small alpha rate(1e-4 thus the choice of 5e-4 instead). However, since reducing this rate helped us gain some points in the accuracy rate on the test set we have decided to keep it.
#
# Finally, and obviously, increasing the size of the training set increases the performance of the neural network. Therfore, using data augmentation will probably help use acheive better performances. We can randomly flip images horizontally, adjust the hue, contrast and saturation with random values. Thus, artificially inflating the size of the training-set by creating random variations of the original input images.
#
# #### Best results
# <table>
# <tr>
#     <td>Accuracy of the network on the 40000 train images:</td>
#     <td>80.19 %</td>
# </tr>
#
#     <td>Accuracy of the network on the 5000 validation images:</td>
#     <td>80.98 %</td>
# <tr>
#     <td> Accuracy of the network on the 10000 test images:</td>
#     <td>73.99 %</td>
#  </tr>
# </table>
